# %% [markdown]
# # **Llamar librerias**

# %%
from sklearn.preprocessing import StandardScaler

import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline 
import os
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # **Llamar base de datos**

# %%
from google.colab import files
uploades=files.upload()
# Out:
#      <input type="file" id="files-93b73c11-88b2-4fb6-a251-18739c3298db" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-93b73c11-88b2-4fb6-a251-18739c3298db">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving prueba.xlsx to prueba.xlsx

# %% [markdown]
# # **Mostrar base de dato en archivo de Excel**

# %%
data=pd.read_excel("prueba.xlsx")
data
# Out:
#       STG   SCG   STR   LPR   PEG       UNS
# 0    0.00  0.10  0.50  0.26  0.05  Very Low
# 1    0.05  0.05  0.55  0.60  0.14       Low
# 2    0.08  0.18  0.63  0.60  0.85      High
# 3    0.20  0.20  0.68  0.67  0.85      High
# 4    0.22  0.22  0.90  0.30  0.90      High
# ..    ...   ...   ...   ...   ...       ...
# 398  0.61  0.78  0.69  0.92  0.58      High
# 399  0.78  0.61  0.71  0.19  0.60    Middle
# 400  0.54  0.82  0.71  0.29  0.77      High
# 401  0.50  0.75  0.81  0.61  0.26    Middle
# 402  0.66  0.90  0.76  0.87  0.74      High
#
# [403 rows x 6 columns]

# %% [markdown]
# # **Mostrar las primeras filas de la data**

# %%
data.head()
# Out:
#     STG   SCG   STR   LPR   PEG       UNS
# 0  0.00  0.10  0.50  0.26  0.05  Very Low
# 1  0.05  0.05  0.55  0.60  0.14       Low
# 2  0.08  0.18  0.63  0.60  0.85      High
# 3  0.20  0.20  0.68  0.67  0.85      High
# 4  0.22  0.22  0.90  0.30  0.90      High

# %% [markdown]
# # **Visualizar los tipos de datos de la columna UNS y sus frecuencias**

# %%
data["UNS"].value_counts()
# Out:
# Low         129
# Middle      122
# High        102
# Very Low     26
# very_low     24
# Name: UNS, dtype: int64

# %% [markdown]
# # **Categorizar variable UNS**

# %%
data["UNS"]=data["UNS"].replace("Very Low",0)
data["UNS"]=data["UNS"].replace("very_low",0)
data["UNS"]=data["UNS"].replace("Low",1)
data["UNS"]=data["UNS"].replace("Middle",2)
data["UNS"]=data["UNS"].replace("High",3)
#.....
data
# Out:
#       STG   SCG   STR   LPR   PEG  UNS
# 0    0.00  0.10  0.50  0.26  0.05    0
# 1    0.05  0.05  0.55  0.60  0.14    1
# 2    0.08  0.18  0.63  0.60  0.85    3
# 3    0.20  0.20  0.68  0.67  0.85    3
# 4    0.22  0.22  0.90  0.30  0.90    3
# ..    ...   ...   ...   ...   ...  ...
# 398  0.61  0.78  0.69  0.92  0.58    3
# 399  0.78  0.61  0.71  0.19  0.60    2
# 400  0.54  0.82  0.71  0.29  0.77    3
# 401  0.50  0.75  0.81  0.61  0.26    2
# 402  0.66  0.90  0.76  0.87  0.74    3
#
# [403 rows x 6 columns]

# %% [markdown]
# # **Visualizar los tipos de datos de la columna UNS y sus frecuencias ya con su categorización**

# %%
data["UNS"].value_counts()
# Out:
# 1    129
# 2    122
# 3    102
# 0     50
# Name: UNS, dtype: int64

# %%
data.head()
# Out:
#     STG   SCG   STR   LPR   PEG  UNS
# 0  0.00  0.10  0.50  0.26  0.05    0
# 1  0.05  0.05  0.55  0.60  0.14    1
# 2  0.08  0.18  0.63  0.60  0.85    3
# 3  0.20  0.20  0.68  0.67  0.85    3
# 4  0.22  0.22  0.90  0.30  0.90    3

# %% [markdown]
# # **Estadisticos descriptivos**

# %%
data.describe()
# Out:
#               STG         SCG         STR         LPR         PEG         UNS
# count  403.000000  403.000000  403.000000  403.000000  403.000000  403.000000
# mean     0.353141    0.355940    0.457655    0.431342    0.456360    1.684864
# std      0.212018    0.215531    0.246684    0.257545    0.266775    0.986195
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.200000    0.200000    0.265000    0.250000    0.250000    1.000000
# 50%      0.300000    0.300000    0.440000    0.330000    0.400000    2.000000
# 75%      0.480000    0.510000    0.680000    0.650000    0.660000    3.000000
# max      0.990000    0.900000    0.950000    0.990000    0.990000    3.000000

# %%
print("la cantidad de dato es =",len(data))
print("existen {} datos en el dataset".format(len(data)))
# Out:
# la cantidad de dato es = 403
# existen 403 datos en el dataset

# %% [markdown]
# # **Datos de los atributos o variables**

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 403 entries, 0 to 402
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   STG     403 non-null    float64
#  1   SCG     403 non-null    float64
#  2   STR     403 non-null    float64
#  3   LPR     403 non-null    float64
#  4   PEG     403 non-null    float64
#  5   UNS     403 non-null    int64
# dtypes: float64(5), int64(1)
# memory usage: 19.0 KB

# %% [markdown]
# # **Visualizar tabla de las frecuencias de la columna UNS**

# %%
pd.DataFrame(np.unique(data["UNS"],return_counts=True),columns=["muy bajo","Bajo","Medio","Alto"]).T
# Out:
#           0    1
# muy bajo  0   50
# Bajo      1  129
# Medio     2  122
# Alto      3  102

# %% [markdown]
# # **Nueva data sin la columna UNS**

# %%
data0=data[["STG","SCG","STR","LPR","PEG"]]
data0
# Out:
#       STG   SCG   STR   LPR   PEG
# 0    0.00  0.10  0.50  0.26  0.05
# 1    0.05  0.05  0.55  0.60  0.14
# 2    0.08  0.18  0.63  0.60  0.85
# 3    0.20  0.20  0.68  0.67  0.85
# 4    0.22  0.22  0.90  0.30  0.90
# ..    ...   ...   ...   ...   ...
# 398  0.61  0.78  0.69  0.92  0.58
# 399  0.78  0.61  0.71  0.19  0.60
# 400  0.54  0.82  0.71  0.29  0.77
# 401  0.50  0.75  0.81  0.61  0.26
# 402  0.66  0.90  0.76  0.87  0.74
#
# [403 rows x 5 columns]

# %% [markdown]
# # **Grafico para análisis de variables de la nueva data**

# %%
sns.pairplot(data0, aspect=1) 
plt.show()

# %% [markdown]
# ## Ahora ....¿Que vamos hacer?
# vamos aplicar los algoritmos de Clustering para el conjunto de datos "data0"
# vamos a aplicar 4 algoritmos:
# 1. K-Mean
# 2. Clustering jerárquico
# 3. DBSCAN
# 4. Shift mean

# %% [markdown]
# # **Aplicando K-Mean**

# %%
from sklearn.cluster import KMeans

clusters = []
for i in range(1, 20):
    km = KMeans(n_clusters=i).fit(data0)
    clusters.append(km.inertia_)
    
fig, ax = plt.subplots(figsize=(8, 6))
sns.lineplot(x=list(range(1, 20)), y=clusters, ax=ax, marker="o")
ax.set_title('Searching for Elbow')
ax.set_xlabel('Clusters')
ax.set_ylabel('Inertia')
plt.show()

# %% [markdown]
# Con la grafica del metodo del codo se puede visualizar que entre 4 a 6 cluster se pueden utilizar, ya que no se logra ver una disminución considerable en la inercia a medida que se aumentan los cluster.

# %% [markdown]
# ## **Aplicando K-Mean con 4 cluster**

# %%
km4 = KMeans(n_clusters=4).fit(data0)
data['Labels_k4'] = km4.labels_
plt.figure(figsize=(8, 6))
sns.scatterplot(data['LPR'], data['PEG'], hue=data['Labels_k4'], palette=sns.color_palette('tab10', 4), s=100)
plt.title('KMeans with 4 Clusters')
plt.show()

# %% [markdown]
# Parece ser una buena opción tomar 4 cluster, debido que los puntos de los cluster se cruzan muy poco.
#
# - Cluster 0: Bajo LPR y PEG Bajo
# - Cluster 1: Alto LPR y PEG Alto
# - Cluster 2: Alto LPR y PEG Bajo
# - Cluster 3: Bajo LPR y PEG Alto

# %%
len(data[data['Labels_k4']==0]), len(data[data['Labels_k4']==1]), len(data[data['Labels_k4']==2]), len(data[data['Labels_k4']==3])
# Out:
# (114, 56, 96, 137)

# %% [markdown]
# # **Calcular el error de detección**

# %%
pd.DataFrame(np.unique(data["UNS"],return_counts=True),columns=["muy bajo","Bajo","Medio","Alto"])
# Out:
#    muy bajo  Bajo  Medio  Alto
# 0         0     1      2     3
# 1        50   129    122   102

# %%
print("error 1 es=",((len(data[data['Labels_k4']==1])-50)/50)*100,"% de la clasificación muy bajo")
# Out:
# error 1 es= 12.0 % de la clasificación muy bajo

# %%
print("error 2 es=",((len(data[data['Labels_k4']==3])-129)/129)*100,"% de la clasificación bajo")
# Out:
# error 2 es= 6.2015503875969 % de la clasificación bajo

# %%
print("error 3 es=",((122-(len(data[data['Labels_k4']==0])))/122)*100,"% de la clasificación medio")
# Out:
# error 3 es= 6.557377049180328 % de la clasificación medio

# %%
print("error 4 es=",((102-(len(data[data['Labels_k4']==2])))/102)*100,"% de la clasificación alto")
# Out:
# error 4 es= 5.88235294117647 % de la clasificación alto

# %%
print("el error de detección promedio para un K-Mean de 4 cluster es=",(np.round((10+6.2015503875969+7.377049180327869+3.9215686274509802)/4,2)),"%")
# Out:
# el error de detección promedio para un K-Mean de 4 cluster es= 6.88 %

# %% [markdown]
# # **Aplicando K-Mean con 5 cluster**

# %%
km5 = KMeans(n_clusters=5).fit(data0)
data['Labels_k5'] = km5.labels_
plt.figure(figsize=(8, 6))
sns.scatterplot(data['LPR'], data['PEG'], hue=data['Labels_k5'], palette=sns.color_palette('tab10', 5), s=100)
plt.title('KMeans with 5 Clusters')
plt.show()

# %% [markdown]
# No parece ser una buena opción tomar 5 cluster, debido que muchos puntos de los diferentes cluster se cruzan.

# %% [markdown]
# # **Aplicando K-Mean con 6 cluster**

# %%
km6 = KMeans(n_clusters=6).fit(data0)
data['Labels_k6'] = km6.labels_
plt.figure(figsize=(8, 6))
sns.scatterplot(data['LPR'], data['PEG'], hue=data['Labels_k6'], palette=sns.color_palette('tab10', 6), s=100)
plt.title('KMeans with 6 Clusters')
plt.show()

# %% [markdown]
# Tampoco parece ser una buena opción tomar 6 cluster, debido que muchos puntos de los diferentes cluster se cruzan.

# %% [markdown]
# # **Aplicando Clusterin Jerárquico (Aglomerativo)**

# %%
from sklearn.cluster import AgglomerativeClustering 

agglom = AgglomerativeClustering(n_clusters=4, linkage='average').fit(data0)

data['Labels_a4'] = agglom.labels_
plt.figure(figsize=(8, 6))
sns.scatterplot(data['LPR'], data['PEG'], hue=data['Labels_a4'], palette=sns.color_palette('tab10', 4), s=100,alpha=0.7)
plt.title('Agglomerative with 4 Clusters')
plt.show()

# %% [markdown]
# No parece ser una buena opción el metodo **aglomerativo o clusterin jerárquico** en comparación con k-Mean para 4 cluster.

# %%
len(data[data['Labels_a4']==0]),len(data[data['Labels_a4']==1]),len(data[data['Labels_a4']==2]),len(data[data['Labels_a4']==3])
# Out:
# (53, 347, 2, 1)

# %% [markdown]
# # **Aplicando DBSCAN**

# %%
from sklearn.cluster import DBSCAN 

db = DBSCAN(eps=11, min_samples=6).fit(data0)

data['Labels_db'] = db.labels_
plt.figure(figsize=(8, 6))
sns.scatterplot(data['LPR'], data['PEG'], hue=data['Labels_db'], palette=sns.color_palette('tab10', np.unique(db.labels_).shape[0]), s=100)
plt.title('DBSCAN with epsilon 11, min samples 6')
plt.show()

# %% [markdown]
# Con el metodo **DBSCAN** solo se observa que toma un solo grupo y no parece ser buena opción.

# %%
len(data[data['Labels_db']==0])
# Out:
# 403

# %% [markdown]
# # **Aplicando Algoritmo Mean Shift**

# %%
from sklearn.cluster import MeanShift, estimate_bandwidth

# The following bandwidth can be automatically detected using
bandwidth = estimate_bandwidth(data0, quantile=0.0819)
ms = MeanShift(bandwidth=bandwidth).fit(data0)

data['Labels_bw'] = ms.labels_
plt.figure(figsize=(8, 6))
sns.scatterplot(data['LPR'], data['PEG'], hue=data['Labels_bw'], palette=sns.color_palette('tab10', np.unique(ms.labels_).shape[0]), s=100)
plt.plot()
plt.title('MeanShift')
plt.show()

# %% [markdown]
# Con el metodo **algoritmo mean shift** no parece ser buena opción.

# %%
len(data[data['Labels_bw']==0]),len(data[data['Labels_bw']==1]),len(data[data['Labels_bw']==2]),len(data[data['Labels_bw']==3])
# Out:
# (266, 62, 35, 40)

# %% [markdown]
# # **Copia de la base de datos original**

# %%
data1=data.copy()

# %%
data1["UNS"].value_counts()
# Out:
# 1    129
# 2    122
# 3    102
# 0     50
# Name: UNS, dtype: int64

# %%
data1["Labels_k4"].value_counts()
# Out:
# 3    137
# 0    114
# 2     96
# 1     56
# Name: Labels_k4, dtype: int64

# %%
data1["UNS_Kmeans"]=data1["Labels_k4"].replace(3,30)
data1["UNS_Kmeans"]=data1["UNS_Kmeans"].replace(0,10)
data1["UNS_Kmeans"]=data1["UNS_Kmeans"].replace(2,3)
data1["UNS_Kmeans"]=data1["UNS_Kmeans"].replace(1,0)
data1["UNS_Kmeans"]=data1["UNS_Kmeans"].replace(30,1)
data1["UNS_Kmeans"]=data1["UNS_Kmeans"].replace(10,2)
data1["UNS_Original"]=data1["UNS"].replace(0,"Muy Bajo")
data1["UNS_Original"]=data1["UNS_Original"].replace(1,"Bajo")
data1["UNS_Original"]=data1["UNS_Original"].replace(2,"Medio")
data1["UNS_Original"]=data1["UNS_Original"].replace(3,"Alto")
data1
# Out:
#       STG   SCG   STR   LPR   PEG  UNS  Labels_k4  Labels_k5  Labels_k6  \
# 0    0.00  0.10  0.50  0.26  0.05    0          0          3          4
# 1    0.05  0.05  0.55  0.60  0.14    1          2          2          1
# 2    0.08  0.18  0.63  0.60  0.85    3          3          0          0
# 3    0.20  0.20  0.68  0.67  0.85    3          1          0          3
# 4    0.22  0.22  0.90  0.30  0.90    3          3          4          0
# ..    ...   ...   ...   ...   ...  ...        ...        ...        ...
# 398  0.61  0.78  0.69  0.92  0.58    3          1          0          3
# 399  0.78  0.61  0.71  0.19  0.60    2          3          4          0
# 400  0.54  0.82  0.71  0.29  0.77    3          3          4          0
# 401  0.50  0.75  0.81  0.61  0.26    2          2          2          1
# 402  0.66  0.90  0.76  0.87  0.74    3          1          0          3
#
#      Labels_a4  Labels_db  Labels_bw  UNS_Kmeans UNS_Original
# ...

# %%
from sklearn.metrics import accuracy_score, mean_absolute_percentage_error

# %%
np.round((1 - accuracy_score(data1["UNS_Kmeans"],data1["UNS"]))*100,2)
# Out:
# 97.02

# %% [markdown]
# el modelo de clasificación KMean tiene un 97.02% de presición

# %%
labels_Labels_k4 = dict(zip(data['UNS'].value_counts().index, data['Labels_k4'].value_counts().index))

labels_Labels_k4
# Out:
# {0: 1, 1: 3, 2: 0, 3: 2}

# %% [markdown]
# - Lo que es 1 en KMean es 0 en UND, Muy bajo
# - Lo que es 3 en KMean es 1 en UND, Bajo
# - Lo que es 0 en KMean es 2 en UND, Medio
# - Lo que es 2 en KMean es 3 en UND, Alto

# %% [markdown]
# # **CONCLUSIÓN**

# %% [markdown]
# El método que mejor se ajusta con 4 cluster para la data analizada es el K-Mean. Tiene un 97.02% de precisión en el modelo de clasificación y además este método nos da un error promedio de detección de 6,88%, es decir, tiene un 93,12% de precisión en meter los datos de clasificación.
